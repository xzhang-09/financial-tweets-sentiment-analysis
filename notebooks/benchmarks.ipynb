# %% [markdown]
# # Benchmark Notes
#
# This notebook is now kept only as a supplementary note. The old benchmark content no longer represents the current project.
#
# The main presentation notebook for this project is `financial_tweets_sentiment_analysis.ipynb`.

# %% [markdown]
# ## Suggested Benchmark Directions
#
# If you want to add benchmarks later, these are the most useful comparison groups:
#
# - TF-IDF + SGDClassifier vs TF-IDF + Linear SVM
# - Baseline vs FinBERT
# - Raw text vs. cleaned text
# - Generalization across different `source` groups
# - Different slices: short text, cashtags, URLs, and news headlines

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from financial_tweets_sentiment_analysis import data

df = data.load_data(str(PROJECT_ROOT / 'datasets' / 'processed' / 'train' / 'train_sample_5000.csv'), num_samples=200)
df.head()
